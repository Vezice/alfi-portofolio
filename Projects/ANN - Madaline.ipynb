# %% [markdown]
# # Madaline

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Import

# %%
import numpy as np

# %% [markdown]
# ### Activation Func

# %%
def aktivasi(x):
  if x < 0:
    return -1
  else:
    return 1

# %% [markdown]
# ### Training

# %%
#Original
def train(train_data,train_target,alpha=0.1,max_epoch=10):
  w = np.random.random((2,2))
  v = np.array([0.5,0.5])
  b = np.random.random(2)
  b = np.append(b,0.5)
  epoch = 0
  v_aktivasi = np.vectorize(aktivasi)
  weight_updated = True

  while weight_updated == True and epoch < max_epoch:
    weight_updated = False

    for data,target in zip(train_data,train_target):
      z_in = np.dot(data,w)
      z_in = z_in + b[:-1]
      z = v_aktivasi(z_in)
      y_in = np.dot(z,v) + b[-1]
      y = v_aktivasi(y_in)

      if y!= target:
        weight_updated = True

        if target == 1:
          index = np.argmin(np.abs(z_in))
          b[index] = b[index] + alpha * (1 - z_in[index])
          w[:, index] = w[:, index] + alpha * (1 - z_in[index])*data
        elif target == -1:
          index = np.where(z_in>0)[0]
          if len(index)==1:
            index = index[0]
          b[index] = b[index] + alpha * (-1 - z_in[index])
          w[:, index] = w[:, index] + alpha * (-1 - z_in[index]) * data
    epoch = epoch +1

  return (w,v,b)
  #Original

# %% [markdown]
# ### Testing

# %%
def test(w,v,b,test_data):
  v_aktivasi = np.vectorize(aktivasi)
  z_in = np.dot(test_data, w)
  z_in = z_in + b[:-1]
  z = v_aktivasi(z_in)
  y_in = np.dot(z, v) + b[-1]
  y = v_aktivasi(y_in)
  return y

# %% [markdown]
# ### Count Accuracy Function

# %%
def calc_accuracy(a, b):
  s = [1 if a[i] == b[i] else 0 for i in range(len(a))]
  return sum(s) / len(a)

# %% [markdown]
# ## Logics

# %% [markdown]
# ### And Logic

# %%
data = np.array([[1,1],[1,-1],[-1,1],[-1,-1]])
target = np.array([1,-1,-1,-1])
(w,v,b) = train(data,target,alpha=0.8,max_epoch=100)
output = test(w,v,b,data)
accuracy = calc_accuracy(output, target)

print('Output:', output)
print('Target:', target)
print('Accuracy:', accuracy)
# Out:
# Output: [ 1 -1 -1 -1]
# Target: [ 1 -1 -1 -1]
# Accuracy: 1.0

# %% [markdown]
# ### OR Logic

# %%
# Bipolar
data = np.array([[1,1],[1,-1],[-1,1],[-1,-1]])
target = np.array([1,1,1,-1])
(w,v,b) = train(data,target,alpha=0.2,max_epoch=100)
output = test(w,v,b,data)
accuracy = calc_accuracy(output, target)

print('Output:', output)
print('Target:', target)
print('Accuracy:', accuracy)
# Out:
# Output: [ 1  1  1 -1]
# Target: [ 1  1  1 -1]
# Accuracy: 1.0

# %%
# Binary
data = np.array([[1,1],[1,0],[0,1],[0,0]])
target = np.array([1,1,1,0])
(w,v,b) = train(data,target,alpha=0.2,max_epoch=100)
output = test(w,v,b,data)
accuracy = calc_accuracy(output, target)

print('Output:', output)
print('Target:', target)
print('Accuracy:', accuracy)
# Out:
# Output: [1 1 1 1]
# Target: [1 1 1 0]
# Accuracy: 0.75

# %% [markdown]
# ### XOR Logic

# %%
data = np.array([[1,1],[1,-1],[-1,1],[-1,-1]])
target = np.array([-1,1,1,-1])
(w,v,b) = train(data,target,alpha=0.2,max_epoch=100)
output = test(w,v,b,data)
accuracy = calc_accuracy(output, target)

print('Output:', output)
print('Target:', target)
print('Accuracy:', accuracy)
# Out:
# Output: [-1  1  1 -1]
# Target: [-1  1  1 -1]
# Accuracy: 1.0

# %% [markdown]
# ### ANDNOT Logic

# %%
data = np.array([[1,1],[1,-1],[-1,1],[-1,-1]])
target = np.array([-1,1,-1,-1])
(w,v,b) = train(data,target,alpha=0.2,max_epoch=100)
output = test(w,v,b,data)
accuracy = calc_accuracy(output, target)

print('Output:', output)
print('Target:', target)
print('Accuracy:', accuracy)
# Out:
# Output: [-1  1 -1 -1]
# Target: [-1  1 -1 -1]
# Accuracy: 1.0

# %% [markdown]
# ### Testing Alpha Score

# %%
data = np.array([[1,1],[1,-1],[-1,1],[-1,-1]])
target = np.array([1,-1,-1,-1])
(w,v,b) = train(data,target,alpha=1.0,max_epoch=100)
output = test(w,v,b,data)
accuracy = calc_accuracy(output, target)

print('Output:', output)
print('Target:', target)
print('Accuracy:', accuracy)
# Out:
# Output: [ 1 -1 -1 -1]
# Target: [ 1 -1 -1 -1]
# Accuracy: 1.0
